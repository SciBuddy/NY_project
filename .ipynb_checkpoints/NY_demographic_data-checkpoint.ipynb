# %%
#Jupytr notebook for NY demographics project
#step one is to load in the data and transform it

#import packages
import numpy as np
import pandas as pd
import requests
from io import StringIO

# define parameters for a request, set up github api
token = '' 
owner = 'SciBuddy'
repo = 'NY_project'

#define file path, will need to make a function for this moving forward.
path = 'productDownload_2021-04-05T122235/ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv'

r = requests.get( # send a request
    'https://api.github.com/repos/{owner}/{repo}/contents/{path}'.format(
    owner=owner, repo=repo, path=path),
    headers={
        'accept': 'application/vnd.github.v3.raw',
        'authorization': 'token {}'.format(token)
            }
    )
# convert string to StringIO object
string_io_obj = StringIO(r.text)

# Load data to df
D2010 = pd.read_csv(string_io_obj, sep=",",header = 0)
print(D2010.columns)

print(D2010.iloc[0,:])
# Out:
# Index(['GEO_ID', 'NAME', 'DP05_0001E', 'DP05_0001M', 'DP05_0001PE',
#        'DP05_0001PM', 'DP05_0002E', 'DP05_0002M', 'DP05_0002PE', 'DP05_0002PM',
#        ...
#        'DP05_0079PE', 'DP05_0079PM', 'DP05_0080E', 'DP05_0080M', 'DP05_0080PE',
#        'DP05_0080PM', 'DP05_0081E', 'DP05_0081M', 'DP05_0081PE',
#        'DP05_0081PM'],
#       dtype='object', length=326)
# GEO_ID                                                        id
# NAME                                        Geographic Area Name
# DP05_0001E               Estimate!!SEX AND AGE!!Total population
# DP05_0001M     Estimate Margin of Error!!SEX AND AGE!!Total p...
# DP05_0001PE               Percent!!SEX AND AGE!!Total population
#                                      ...
# DP05_0080PM    Percent Margin of Error!!HISPANIC OR LATINO AN...
# DP05_0081E                         Estimate!!Total housing units
# DP05_0081M         Estimate Margin of Error!!Total housing units
# ...

# %%
col = get_demo_data('ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv')
name_key = pd.DataFrame(list(col.columns),columns = 'Descirption',index = range(0,len(col.columns)))
print(name_key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-308-a6e9f2672e61> in <module>
#       1 col = get_demo_data('ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv')
# ----> 2 name_key = pd.DataFrame(list(col.columns),columns = 'Descirption',index = range(0,len(col.columns)))
#       3 print(name_key)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     521                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     522                 else:
# --> 523                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     524             else:
#     525                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ...

# %%
import numpy as np
import pandas as pd
import requests
from io import StringIO

files = ('ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2011.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2012.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2013.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2014.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2015.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2016.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2017.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2018.DP05_data_with_overlays_2021-04-05T122219.csv',
         'ACSDP5Y2019.DP05_data_with_overlays_2021-04-05T122219.csv',
        ) #create list of file names

def get_demo_data(file):
    #created by GB on 4/5/2020
    #purpose is to grab csv files from github using input file name
    #returns the data in dataframe
    
    token = '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' 
    owner = 'SciBuddy'
    repo = 'NY_project'
    path1 = 'productDownload_2021-04-05T122235/'
    
    path = path1+file #creates the full path
    
    
    r = requests.get( # send a request
    'https://api.github.com/repos/{owner}/{repo}/contents/{path}'.format(
    owner=owner, repo=repo, path=path),
    headers={
        'accept': 'application/vnd.github.v3.raw',
        'authorization': 'token {}'.format(token)
            }
    )
    # convert string to StringIO object
    string_io_obj = StringIO(r.text)

    # Load data to df
    df = pd.read_csv(string_io_obj, sep=",",header = 0)
    
    return df


#get column names 
col = get_demo_data('ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv')
master_data = pd.DataFrame(columns = list(col.columns)) #initalize with column names
#file = ('ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv')
#data = get_demo_data(file)
#master_data.append(data)
all_colnames = []  
i = 0
for file in files:
    data = get_demo_data(file)
    if i == 0:
        data1 = data
    elif i == 1:
        data2 = data
    elif i == 2:
        data3 = data
    elif i == 3:
        data4 = data
    elif i == 4:
        data5 = data    
    elif i == 5:
        data6 = data
    elif i == 6:
        data7 = data
    elif i == 7:
        data4 = data
    elif i == 8:
        data8 = data 
    i+= 1
    
    #master_data = pd.concat([master_data,data])

# %%
pd.read_csv?

# %%
data1_cols = data1.columns
data2_cols = data2.columns
dif1 = data1_cols.intersection(data2_cols, sort = False)
dif2 = data2_cols.intersection(data1_cols, sort = False)

print(dif1)
print(dif2)
# Out:
# Index(['id', 'Geographic Area Name', 'Estimate!!SEX AND AGE!!Total population',
#        'Percent!!SEX AND AGE!!Total population',
#        'Percent Margin of Error!!SEX AND AGE!!Total population',
#        'Estimate!!SEX AND AGE!!Male', 'Percent!!SEX AND AGE!!Male',
#        'Percent Margin of Error!!SEX AND AGE!!Male',
#        'Estimate!!SEX AND AGE!!Female', 'Percent!!SEX AND AGE!!Female',
#        ...
#        'Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races',
#        'Estimate!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race',
#        'Percent!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race',
#        'Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race',
# ...

# %%
len(all_colnames)
def unique(list1):
     
    # insert the list to the set
    list_set = set(list1)
    # convert the set to the list
    unique_list = (list(list_set))
    for x in unique_list:
        print(x)
        
unique(all_colnames)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-213-58b1afe0fdb1> in <module>
#       8     for x in unique_list:
#       9         print(x)
# ---> 10 unique(all_colnames)
#      11
#
# <ipython-input-213-58b1afe0fdb1> in unique(list1)
#       3
#       4     # insert the list to the set
# ----> 5     list_set = set(list1)
#       6     # convert the set to the list
#       7     unique_list = (list(list_set))
#
# TypeError: unhashable type: 'list'

# %%
data.head(3)
# Out:
#                id       Geographic Area Name  \
# 0  0500000US36001    Albany County, New York
# 1  0500000US36003  Allegany County, New York
# 2  0500000US36005     Bronx County, New York
#
#    Estimate!!SEX AND AGE!!Total population  \
# 0                                   306968
# 1                                    46688
# 2                                  1435068
#
#   Margin of Error!!SEX AND AGE!!Total population  \
# 0                                          *****
# 1                                          *****
# 2                                          *****
#
#    Percent!!SEX AND AGE!!Total population  \
# 0                                  306968
# 1                                   46688
# 2                                 1435068
#
#   Percent Margin of Error!!SEX AND AGE!!Total population  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
#
# ...

# %%
876-358
# Out:
# 518

# %%
#test type of data, all data types seem consistent
#find useful columns??
#'Estimate!!RACE!!One race!!Black or African American'
#'Percent!!RACE!!One race!!Black or African American'

#find all single race estimates 
single_race_col_estim = [col for col in D2010 if col.startswith('Estimate!!RACE!!One race!!')]
single_race_col_percent = [col for col in D2010 if col.startswith('Percent!!RACE!!One race!!')]
single_race_col_estim
# Out:
# ['Estimate!!RACE!!One race!!White',
#  'Estimate!!RACE!!One race!!Black or African American',
#  'Estimate!!RACE!!One race!!American Indian and Alaska Native',
#  'Estimate!!RACE!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping',
#  'Estimate!!RACE!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping',
#  'Estimate!!RACE!!One race!!American Indian and Alaska Native!!Navajo tribal grouping',
#  'Estimate!!RACE!!One race!!American Indian and Alaska Native!!Sioux tribal grouping',
#  'Estimate!!RACE!!One race!!Asian',
#  'Estimate!!RACE!!One race!!Asian!!Asian Indian',
#  'Estimate!!RACE!!One race!!Asian!!Chinese',
#  'Estimate!!RACE!!One race!!Asian!!Filipino',
#  'Estimate!!RACE!!One race!!Asian!!Japanese',
#  'Estimate!!RACE!!One race!!Asian!!Korean',
#  'Estimate!!RACE!!One race!!Asian!!Vietnamese',
#  'Estimate!!RACE!!One race!!Asian!!Other Asian',
#  'Estimate!!RACE!!One race!!Native Hawaiian and Other Pacific Islander',
# ...

# %%
total_white = sum(D2010['Estimate!!RACE!!One race!!White'])
total_white
#start by looping through these and summing getting total NY race break down
#Can then do % of population in each county
#% of black  population in each county, % of black population in each county

#individual county calcs
#calculate %s on my own for each county, estimate of each / total
# Out:
# 12764402

# %%
# Out:
# 0     78.9
# 1     96.5
# 2     21.9
# 3     88.7
# 4     93.5
#       ...
# 57    94.5
# 58    93.6
# 59    67.9
# 60    90.3
# 61    97.4
# Name: Percent!!RACE!!One race!!White, Length: 62, dtype: float64
