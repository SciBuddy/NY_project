# %%
#Jupytr notebook for NY demographics project
#step one is to load in the data and transform it

import pandas as pd
url = 'https://raw.githubusercontent.com/SciBuddy/NY_project/main/productDownload_2021-04-05T122235/ACSDP5Y2010.DP05_data_with_overlays_2021-04-05T122219.csv?token=ATPN2LZAQACGDZ5YFPVPATTANM6LC'
D2010 = pd.read_csv(url, error_bad_lines=False)
print(type(D2010))
D2010.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            GEO_ID                     NAME  \
# 0              id     Geographic Area Name
# 1  0500000US36001  Albany County, New York
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                   304032
#
#                                           DP05_0001M  \
# 0  Estimate Margin of Error!!SEX AND AGE!!Total p...
# 1                                              *****
#
#                               DP05_0001PE  \
# 0  Percent!!SEX AND AGE!!Total population
# 1                                  304032
#
#                                          DP05_0001PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                     DP05_0002E                                   DP05_0002M  \
# 0  Estimate!!SEX AND AGE!!Male  Estimate Margin of Error!!SEX AND AGE!!Male
# ...
